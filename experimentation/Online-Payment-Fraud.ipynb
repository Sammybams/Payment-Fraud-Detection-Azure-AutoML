# %%
# import dependencies
import pandas as pd

# %%
fraud = pd.read_csv("data/fraud_dataset_example.csv")

# %%
fraud.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
fraud.describe()
# Out:
#                 step        amount  oldbalanceOrg  newbalanceOrig  \
# count  101613.000000  1.016130e+05   1.016130e+05    1.016130e+05
# mean        8.523457  1.740901e+05   9.071753e+05    9.234992e+05
# std         1.820681  3.450199e+05   2.829575e+06    2.867319e+06
# min         1.000000  3.200000e-01   0.000000e+00    0.000000e+00
# 25%         8.000000  1.001659e+04   0.000000e+00    0.000000e+00
# 50%         9.000000  5.338541e+04   2.019047e+04    0.000000e+00
# 75%        10.000000  2.124984e+05   1.947150e+05    2.192178e+05
# max        10.000000  1.000000e+07   3.893942e+07    3.894623e+07
#
#        oldbalanceDest  newbalanceDest        isFraud  isFlaggedFraud
# count    1.016130e+05    1.016130e+05  101613.000000        101613.0
# mean     8.810428e+05    1.183998e+06       0.001142             0.0
# std      2.399949e+06    2.797761e+06       0.033768             0.0
# min      0.000000e+00    0.000000e+00       0.000000             0.0
# ...

# %%
# feature engineering
fraud['percentOut'] = fraud['amount']/fraud['oldbalanceOrg']

# %%
# preview
fraud.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    percentOut
# 0    0.057834
# 1    0.087735
# 2    1.000000
# 3    1.000000
# 4    0.280795

# %%
fraud['isFraud'].value_counts()
# Out:
# 0    101497
# 1       116
# Name: isFraud, dtype: int64

# %%
fraud['step'].value_counts()
# Out:
# 9     37628
# 10    28887
# 8     21097
# 7      6837
# 1      2708
# 6      1660
# 2      1014
# 5       665
# 4       565
# 3       552
# Name: step, dtype: int64

# %%
fraud['type'].unique()
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
#       dtype=object)

# %%
fraud.loc[fraud['percentOut']>1]
# Out:
#         step      type      amount     nameOrig  oldbalanceOrg  \
# 8          1   PAYMENT     4024.36  C1265012928        2671.00
# 10         1     DEBIT     9644.94  C1900366749        4465.00
# 13         1   PAYMENT    11633.76  C1716932897       10127.00
# 15         1  CASH_OUT   229133.94   C905080434       15325.00
# 16         1   PAYMENT     1563.82   C761750706         450.00
# ...      ...       ...         ...          ...            ...
# 101608    10   PAYMENT     7477.02   C513257306         785.00
# 101609    10  CASH_OUT   282252.35   C210473293      220339.29
# 101610    10   PAYMENT    17289.01   C807582280           0.00
# 101611    10  TRANSFER  1347146.45  C1315779140        1605.00
# 101612    10  CASH_OUT   469539.21   C515691325       31133.00
#
#         newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 8                  0.0  M1176932104            0.00            0.00        0
# ...

# %%
fraud.loc[fraud['percentOut']==float('inf')]
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 29         1   PAYMENT    9920.52   C764826684            0.0             0.0
# 30         1   PAYMENT    3448.92  C2103763750            0.0             0.0
# 31         1   PAYMENT    4206.84   C215078753            0.0             0.0
# 32         1   PAYMENT    5885.56   C840514538            0.0             0.0
# 33         1   PAYMENT    5307.88  C1768242710            0.0             0.0
# ...      ...       ...        ...          ...            ...             ...
# 101569    10  TRANSFER  382833.44   C592591740            0.0             0.0
# 101570    10  TRANSFER  212921.38    C27914407            0.0             0.0
# 101595    10  CASH_OUT  337447.20  C1456319459            0.0             0.0
# 101600    10  CASH_OUT  484955.57   C645274928            0.0             0.0
# 101610    10   PAYMENT   17289.01   C807582280            0.0             0.0
#
# ...

# %%
fraud.loc[fraud['percentOut']>1]['isFraud'].value_counts()
# Out:
# 0    58221
# 1        5
# Name: isFraud, dtype: int64

# %%
fraud.loc[fraud['percentOut']==float('inf'), 'percentOut'] = float(0)

# %%
fraud.loc[fraud['percentOut']==0].head(10)
# Out:
#     step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 29     1   PAYMENT   9920.52   C764826684            0.0             0.0
# 30     1   PAYMENT   3448.92  C2103763750            0.0             0.0
# 31     1   PAYMENT   4206.84   C215078753            0.0             0.0
# 32     1   PAYMENT   5885.56   C840514538            0.0             0.0
# 33     1   PAYMENT   5307.88  C1768242710            0.0             0.0
# 34     1   PAYMENT   5031.22   C247113419            0.0             0.0
# 35     1   PAYMENT  24213.67  C1238616099            0.0             0.0
# 44     1   PAYMENT   5086.48   C598357562            0.0             0.0
# 48     1  CASH_OUT   5346.89   C512549200            0.0             0.0
# 79     1  TRANSFER  77957.68   C207471778            0.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 29  M1940055334             0.0            0.00        0               0
# ...

# %%
# export new dataframe to csv
fraud.to_csv("data/fraud_dataset_engineered.csv", index=False)
